# %%
import os
os.chdir("/Users/mac/Desktop/Dinger")

# %%
from Dinger.controller import Controller

# %%
controller = Controller()

# %% [markdown]
# ### (1) Main 함수로 controller 사용하기

# %%
controller.main()

# %% [markdown]
# ### (2) Method 하나씩 돌려보기

# %% [markdown]
# ### get_standard_df

# %%
controller.get_standard_df()
# Out:
# 한국 시장의 기준값 데이터 프레임을 조회합니다.
#                  BPS   PER  PBR     EPS  DIV     DPS      매출액     영업이익  \
# SEC_NM_KOR
# IT          12561.88 26.01 1.89 1116.41 0.89  148.30  2965.95   399.54
# 건강관리        10434.95 26.25 3.42  814.03 0.64  124.79   540.08    51.22
# 경기관련소비재     23448.37 17.90 1.31 2505.02 1.60  438.85  4310.53   272.28
# 금융          31795.46  6.74 0.69 3783.89 4.46  823.24 25541.65  1591.06
# 산업재         20988.79 34.75 1.43 1636.03 1.67  333.29  5517.67   424.33
# 소재          64600.90 14.44 1.29 6795.96 1.84  800.91  4535.81   378.23
# 에너지         36247.31 22.77 1.59 3023.58 1.62 1140.78 16907.61  1985.81
# 유틸리티       106087.00 32.45 1.14 5693.65 2.90 1307.35 18977.24 -3598.53
# 커뮤니케이션서비스   16708.39 23.93 1.96 2776.34 0.83  269.54  2445.65   230.65
# 필수소비재       60567.13 12.23 1.24 4289.28 1.78  719.17  3866.59   260.45
#
#               당기순이익   ROA      ROE   베타    MKT_VAL
# SEC_NM_KOR
# IT           304.36  2.79     4.01 1.01  764310.56
# ...

# %%
controller.get_standard_df()
# Out:
# 미국 시장의 기준값 데이터 프레임을 저장합니다.

# %%
controller.get_standard_df()
# Out:
# 한국 시장의 기준값 데이터 프레임을 저장합니다.

# %%
controller.get_standard_df()
# Out:
# 미국 시장의 기준값 데이터 프레임을 저장합니다.

# %% [markdown]
# ### get_score_df

# %%
controller.get_score_df()
# Out:
# 한국 시장의 스코어 데이터 프레임을 조회합니다.
#        CMP_KOR SEC_NM_KOR       BPS   PER  PBR      EPS  DIV      DPS  \
# 종목코드
# 005380     현대차    경기관련소비재 289609.00  9.33 0.61 18979.00 2.82  5000.00
# 000270      기아    경기관련소비재  87073.00  5.99 0.82 11874.00 4.22  3000.00
# 012330   현대모비스    경기관련소비재 387397.00  7.90 0.52 25645.00 1.98  4000.00
# 051900  LG생활건강    경기관련소비재 321556.00 12.64 1.98 50395.00 1.88 12000.00
# 090430  아모레퍼시픽    경기관련소비재  69049.00 36.88 1.51  2820.00 0.94   980.00
# ...        ...        ...       ...   ...  ...      ...  ...      ...
# 070590  한솔인티큐브         IT   1931.00 67.92 0.84    24.00 0.00     0.00
# 372800  아이티아이즈         IT   5035.00  0.00 1.61     0.00 0.00     0.00
# 033200     모아텍         IT   7713.00  0.00 0.80     0.00 0.00     0.00
# 032960    동일기연         IT  17895.00  4.65 0.60  2312.00 0.37    40.00
# 321260    프로이천         IT   1005.00  0.00 2.10     0.00 0.95    20.00
#
#              매출액     영업이익    당기순이익   ROA   ROE   베타     MKT_VAL  Score
# 종목코드
# ...

# %%
controller.get_score_df()
# Out:
# 미국 시장의 스코어 데이터 프레임을 조회합니다.
#     Symbol                  Name                  Sector  \
# 0      MMM                    3M             Industrials
# 1      AOS           A. O. Smith             Industrials
# 2      ABT                Abbott             Health Care
# 3     ABBV                AbbVie             Health Care
# 4     ABMD               Abiomed             Health Care
# ..     ...                   ...                     ...
# 498    YUM           Yum! Brands  Consumer Discretionary
# 499   ZBRA    Zebra Technologies  Information Technology
# 500    ZBH         Zimmer Biomet             Health Care
# 501   ZION  Zions Bancorporation              Financials
# 502    ZTS                Zoetis             Health Care
#
#                                Industry          Sales        Revenue  \
# 0              Industrial Conglomerates 35090000000.00  4150000000.00
# 1                     Building Products  3850000000.00   517200000.00
# ...

# %%
controller.get_score_df()
# Out:
# 한국 시장의 스코어 데이터 프레임을 저장합니다.

# %%
controller.get_score_df()
# Out:
# 미국 시장의 스코어 데이터 프레임을 저장합니다.

# %% [markdown]
# ### get_top_n_sectors_df

# %%
controller.get_top_n_sectors_df()
# Out:
# 한국 시장의 상위 섹터 데이터 프레임을 조회합니다.
#                  BPS   PER  PBR     EPS  DIV     DPS      매출액     영업이익  \
# SEC_NM_KOR
# 유틸리티       106087.00 32.45 1.14 5693.65 2.90 1307.35 18977.24 -3598.53
# 건강관리        10434.95 26.25 3.42  814.03 0.64  124.79   540.08    51.22
# 필수소비재       60567.13 12.23 1.24 4289.28 1.78  719.17  3866.59   260.45
#
#               당기순이익   ROA      ROE   베타   MKT_VAL  Score
# SEC_NM_KOR
# 유틸리티       -2754.82  3.25     5.85 0.39 624011.76   7.06
# 건강관리          46.90 -1.27 -1461.58 0.96 347073.89   5.54
# 필수소비재        183.34  2.52     4.08 0.73 274516.05   5.15

# %%
controller.get_top_n_sectors_df()
# Out:
# 미국 시장의 상위 섹터 데이터 프레임을 조회합니다.
#                                   Sales         Revenue           MarCap  \
# Sector
# Information Technology 1692280000000.00 382109500000.00 9345480000000.00
# Industrials            1454580000000.00 139600200000.00 2797520000000.00
# Consumer Discretionary 1965600000000.00 166098500000.00 4394990000000.00
#
#                            PER     PBR    ROA     ROE       Volume    Price  \
# Sector
# Information Technology 4116.26  816.42 908.30 1788.40 456585087.00 13532.74
# Industrials            1657.23  374.47 629.90 1412.30  84586644.00 11227.02
# Consumer Discretionary 1437.25 1620.89 514.60   79.00 240235191.00 16740.91
#
#                         Beta  DIVIDEND  Sales_score  Revenue_score  \
# Sector
# Information Technology 89.69     84.63        18.00          16.00
# Industrials            79.24     99.59        21.00          22.00
# Consumer Discretionary 78.83     82.07        11.00          17.00
#
# ...

# %%
controller.get_top_n_sectors_df()
# Out:
# 한국 시장의 상위 섹터 데이터 프레임을 저장합니다.

# %%
controller.get_top_n_sectors_df()
# Out:
# 미국 시장의 상위 섹터 데이터 프레임을 저장합니다.

# %% [markdown]
# ### get_universe_df

# %%
controller.get_universe_df()
# Out:
# ===입력 가능 섹터 리스트===
# ['경기관련소비재', '건강관리', '커뮤니케이션서비스', '금융', '에너지', '산업재', '유틸리티', '필수소비재', '소재', 'IT']
# 한국 시장의 유니버스 데이터 프레임을 조회합니다.
#          CMP_KOR SEC_NM_KOR       BPS   PER  PBR      EPS   DIV     DPS  \
# 종목코드
# 137310  에스디바이오센서       건강관리  21658.00  2.51 1.27 10918.00  4.61 1266.00
# 145720       덴티움       건강관리  33841.00 13.55 2.58  6434.00  0.29  250.00
# 096530        씨젠       건강관리  20971.00  2.65 1.31 10359.00  3.65 1000.00
# 100120       뷰웍스       건강관리  20479.00  9.69 1.69  3575.00  2.16  750.00
# 000640  동아쏘시오홀딩스       건강관리 154410.00 10.23 0.65  9768.00  1.50 1500.00
# 005830    DB손해보험         금융 110605.00  3.83 0.50 14482.00  6.31 3500.00
# 055550      신한지주         금융  88548.00  4.78 0.39  7308.00  5.62 1960.00
# 105560      KB금융         금융 121808.00  4.18 0.38 11134.00  6.32 2940.00
# 001450      현대해상         금융  63866.00  5.67 0.47  5286.00  4.94 1480.00
# 016360      삼성증권         금융  68096.00  2.89 0.46 10810.00 12.16 3800.00
# ...

# %%
controller.get_universe_df()
# Out:
# ===입력 가능 섹터 리스트===
# ['Industrials', 'Health Care', 'Information Technology', 'Communication Services', 'Consumer Staples', 'Consumer Discretionary', 'Utilities', 'Financials', 'Materials', 'Real Estate', 'Energy']
# 존재하지 않는 섹터입니다.
# 미국 시장의 유니버스 데이터 프레임을 조회합니다.
#     Symbol                       Name       Sector  \
# 104    CVX        Chevron Corporation       Energy
# 124    COP             ConocoPhillips       Energy
# 190    XOM                 ExxonMobil       Energy
# 295    MPC         Marathon Petroleum       Energy
# 466    VLO              Valero Energy       Energy
# 2      ABT                     Abbott  Health Care
# 3     ABBV                     AbbVie  Health Care
# 39    AMGN                      Amgen  Health Care
# 307    MRK                Merck & Co.  Health Care
# 370    PFE                     Pfizer  Health Care
# 0      MMM                         3M  Industrials
# 288    LMT            Lockheed Martin  Industrials
# ...

# %%
controller.get_universe_df()
# Out:
# 한국 시장의 유니버스 데이터 프레임을 저장합니다.

# %%
controller.get_universe_df()
# Out:
# ===입력 가능 섹터 리스트===
# ['Industrials', 'Health Care', 'Information Technology', 'Communication Services', 'Consumer Staples', 'Consumer Discretionary', 'Utilities', 'Financials', 'Materials', 'Real Estate', 'Energy']
# 존재하지 않는 섹터입니다.
# 미국 시장의 유니버스 데이터 프레임을 저장합니다.

# %% [markdown]
# ### get_initial_portfolio_df

# %%
controller.get_initial_portfolio_df()
# Out:
# 한국 시장의 최초 포트폴리오 데이터 프레임을 조회합니다.
#          CMP_KOR SEC_NM_KOR       BPS   PER  PBR      EPS  DIV     DPS  \
# 종목코드
# 005830    DB손해보험         금융 110605.00  3.83 0.50 14482.00 6.31 3500.00
# 055550      신한지주         금융  88548.00  4.78 0.39  7308.00 5.62 1960.00
# 105560      KB금융         금융 121808.00  4.18 0.38 11134.00 6.32 2940.00
# 137310  에스디바이오센서       건강관리  21658.00  2.51 1.27 10918.00 4.61 1266.00
# 145720       덴티움       건강관리  33841.00 13.55 2.58  6434.00 0.29  250.00
# 096530        씨젠       건강관리  20971.00  2.65 1.31 10359.00 3.65 1000.00
#
#              매출액     영업이익    당기순이익   ROA   ROE   베타     MKT_VAL  Score
# 종목코드
# 005830  59734.00  3908.00  2983.00  1.80 19.10 0.55  2593404.00  13.00
# 055550  75869.00 17492.00 13399.00  0.80 11.50 0.73 14679149.00  12.00
# 105560 257208.00 16002.00 13080.00  0.80 11.70 0.74 14640560.00  12.00
# 137310   7950.00  3481.00  3386.00 48.60 63.70 0.13   992180.00  14.00
# ...

# %% [markdown]
# ### get_portfolio_ohlcv

# %%
ohlcv = controller.get_portfolio_ohlcv(ratio=False)
ohlcv
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#         005830   055550   105560  001450  016360        ABT        MRK  \
# Open     54800    35450    45550   30600   31350     103.18      92.27
# High     57400    36250    47100   31400   31950     103.92      93.36
# Low      53800    35400    45550   30400   31300     100.79      91.74
# Close    56800    35700    46750   31150   31700     100.91      92.18
# Volume  156329  1157733  1258433  274285  223412 6087200.00 9847600.00
#
#                PFE
# Open         42.89
# High         43.38
# Low          42.36
# Close        42.86
# Volume 16980500.00

# %%
ohlcv = controller.get_portfolio_ohlcv(ratio=True)
ohlcv
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#         005830   055550   105560   001450  016360      ABT      MRK      PFE
# Open   0.01859  0.01868  0.01902  0.02000 0.00481  0.05361  0.03095  0.02706
# High   0.03986  0.02113  0.03289  0.02782 0.00789  0.00815  0.00690  0.00510
# Low    0.00186  0.01871  0.02360  0.02703 0.00968  0.03184  0.02767  0.01583
# Close  0.04029  0.02292  0.04586  0.02805 0.02258 -0.01522 -0.00335 -0.00279
# Volume 0.02531 -0.20617 -0.09287 -0.25406 0.01255 -0.02619  0.04954 -0.26603

# %% [markdown]
# ### get_rebalanced

# %%
rebalanced_portfolio = controller.get_rebalanced()
rebalanced_portfolio
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [0.06686101,
#  0.11355152,
#  0.11447301,
#  0.1145426,
#  0.10967606,
#  0.10794546,
#  0.11660503,
#  0.10678197,
#  0.14956334]

# %%
from Dinger import info

info.now_portfolio
# Out:
# [0.06686101,
#  0.11355152,
#  0.11447301,
#  0.1145426,
#  0.10967606,
#  0.10794546,
#  0.11660503,
#  0.10678197,
#  0.14956334]
